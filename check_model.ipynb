# %%
import cv2
from retinaface import pre_trained_models

# %%
help(pre_trained_models)
# Out:
# Help on module retinaface.pre_trained_models in retinaface:
#
# NAME
#     retinaface.pre_trained_models
#
# CLASSES
#     builtins.tuple(builtins.object)
#         model
#
#     class model(builtins.tuple)
#      |  model(url, model)
#      |
#      |  model(url, model)
#      |
#      |  Method resolution order:
#      |      model
#      |      builtins.tuple
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __getnewargs__(self)
#      |      Return self as a plain tuple.  Used by copy and pickle.
#      |
#      |  __repr__(self)
#      |      Return a nicely formatted representation string
#      |
#      |  _asdict(self)
#      |      Return a new dict which maps field names to their values.
#      |
#      |  _replace(self, /, **kwds)
#      |      Return a new model object replacing specified fields with new values
#      |
#      |  ----------------------------------------------------------------------
# ...
